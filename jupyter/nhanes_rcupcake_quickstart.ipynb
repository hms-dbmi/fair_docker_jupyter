# %%
library(devtools)
if (file.exists(Sys.getenv("TAR")) == FALSE)  {
    Sys.setenv(TAR = "/bin/tar")
}
options(repos = c("https://cloud.r-project.org/"))

# %%
library(knitr)
library(plotly)
library(httr)
library(Rcupcake)
# Out:
# Loading required package: ggplot2
#
# Attaching package: ‘plotly’
#
# The following object is masked from ‘package:ggplot2’:
#
#     last_plot
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# The following object is masked from ‘package:graphics’:
#
#     layout
#
#
# Attaching package: ‘httr’
#
# The following object is masked from ‘package:plotly’:
#
#     config

# %%
setToken("eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJzYW1scHxmb29AYmFyLmNvbSIsImF1ZCI6InNhbWxwfGZvb0BiYXIuY29tIiwiaXNzIjoiYmFyIiwiZXhwIjoxNjIwMjM4MjkyLCJpYXQiOjE1MzM4MzgyOTIsImp0aSI6IkZvbyJ9.eT_b84ZHy-zXdeOQ7ho1cfy3DBBSYoMDF2fEdNbRfEk")
httr::set_config(config(ssl_verifypeer = 0L, ssl_verifyhost = 0L))

PICSURE_URL <- "http://irct:8080/"

# %%
nhanesDisease <- get.children( 
   url         = "http://nginx/", 
   fieldname   = "/i2b2-wildfly-default/Demo/questionnaire/questionnaire/disease/"
  )
nhanesDisease
# Out:
#  [1] "/i2b2-wildfly-default/Demo/questionnaire/questionnaire/disease/Any CAD (self report)/"
#  [2] "/i2b2-wildfly-default/Demo/questionnaire/questionnaire/disease/Any cancer or malignancy?/"
#  [3] "/i2b2-wildfly-default/Demo/questionnaire/questionnaire/disease/Any Diabetes (FBG >= 126 mg per dL or self-report)/"
#  [4] "/i2b2-wildfly-default/Demo/questionnaire/questionnaire/disease/Any family with heart attack or angina?/"
#  [5] "/i2b2-wildfly-default/Demo/questionnaire/questionnaire/disease/Any Hypertension? (BP >= 139 per 90 or self report)/"
#  [6] "/i2b2-wildfly-default/Demo/questionnaire/questionnaire/disease/any_cad/"
#  [7] "/i2b2-wildfly-default/Demo/questionnaire/questionnaire/disease/any_chronic_disease/"
#  [8] "/i2b2-wildfly-default/Demo/questionnaire/questionnaire/disease/bladder_cancer_self_report/"
#  [9] "/i2b2-wildfly-default/Demo/questionnaire/questionnaire/disease/blood_cancer_self_report/"
# ...
